# %% [markdown]
# # Phase-0 GRPO Hardware Validation (Kaggle T4x2)

# %%
# !pip install torch==2.5.1 transformers==4.49.0 trl==0.15.1 peft bitsandbytes accelerate

# %%
# !apt-get update && apt-get install -y chromium-browser
# !npm install -g puppeteer

# %%
# Dataset mounted at /kaggle/input/phase0-grpo-validation
# !python /kaggle/input/phase0-grpo-validation/scripts/kaggle_validation_driver.py
